# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 29.6 MB/s eta 0:00:00

# %%
import os

train_images = "/content/drive/MyDrive/yolotask/images/train"
train_labels = "/content/drive/MyDrive/yolotask/labels/train"

# %%
from ultralytics import YOLO

model = YOLO("yolo11s.pt")
model.train(
    data="/content/drive/MyDrive/yolotask/data.yaml",
    epochs=50,
    imgsz=640,
    batch=8,
    project="/content/drive/MyDrive/yolo_training",
    name="person_detector"
)
# Out:
# Ultralytics 8.4.56 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model = YOLO("/content/drive/MyDrive/yolo_training/person_detector/weights/best.pt")

# Test image
results = model.predict(
    source="/content/drive/MyDrive/yolotask/images/test",
    conf=0.25,
    save=True
)
# Out:
# image 1/50 /content/drive/MyDrive/yolotask/images/test/video_one10.jpg: 384x640 9 persons, 82.7ms
# image 2/50 /content/drive/MyDrive/yolotask/images/test/video_one105.jpg: 384x640 3 persons, 20.4ms
# image 3/50 /content/drive/MyDrive/yolotask/images/test/video_one24.jpg: 384x640 9 persons, 24.0ms
# image 4/50 /content/drive/MyDrive/yolotask/images/test/video_one28.jpg: 384x640 8 persons, 16.4ms
# image 5/50 /content/drive/MyDrive/yolotask/images/test/video_one30.jpg: 384x640 7 persons, 25.0ms
# image 6/50 /content/drive/MyDrive/yolotask/images/test/video_one32.jpg: 384x640 7 persons, 15.3ms
# image 7/50 /content/drive/MyDrive/yolotask/images/test/video_one38.jpg: 384x640 7 persons, 25.2ms
# image 8/50 /content/drive/MyDrive/yolotask/images/test/video_one44.jpg: 384x640 8 persons, 28.0ms
# image 9/50 /content/drive/MyDrive/yolotask/images/test/video_one46.jpg: 384x640 6 persons, 40.1ms
# ...

# %% [markdown]
# #**Random Forest Classification Using Iris Dataset**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
iris = load_iris()

# %%
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
iris.data
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
x = iris.data
y = iris.target

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
model.predict(x_test)
# Out:
# array([0, 1, 2, 0, 1, 1, 1, 1, 2, 2, 2, 0, 0, 2, 1, 1, 1, 1, 2, 0, 0, 0,
#        0, 1, 1, 0, 0, 2, 0, 2])

# %%
model.score(x_test,y_test)
# Out:
# 0.9333333333333333

# %%
model = RandomForestClassifier(n_estimators=10)
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.9333333333333333

# %%
model = RandomForestClassifier(n_estimators=30)
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.9333333333333333

# %%
model = RandomForestClassifier(n_estimators=27)
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.9333333333333333

# %% [markdown]
# #**Save and Load**

# %% [markdown]
# **using pickle**

# %%
import pickle

# %%
with open("model_pickle",'wb') as file:
  model_pickle=pickle.dump(model,file)

# %%
with open("model_pickle",'rb') as file:
  pm = pickle.load(file)

# %%
pm.score(x_test,y_test)
# Out:
# 0.9333333333333333

# %% [markdown]
# **using joblib**

# %%
import joblib

# %%
joblib.dump(model,"R_model")
# Out:
# ['R_model']

# %%
jm = joblib.load("R_model")

# %%
jm.score(x_test,y_test)
# Out:
# 0.9333333333333333
